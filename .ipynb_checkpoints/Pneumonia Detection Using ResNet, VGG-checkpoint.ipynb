# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
import keras
import skimage.io as io
from skimage.transform import  rescale,resize
from skimage.color import rgb2gray
import cv2
from tensorflow.keras import layers
from tensorflow.keras.applications import ResNet50,VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D, AveragePooling2D
from tensorflow.keras.models import Model
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras.optimizers import Adam
from IPython.display import Image
from keras import backend as K

from sklearn.metrics import roc_curve, auc

# %%
path = os.getcwd()

print(path)
# Out:
# C:\Users\shameen.shrestha\Downloads\Pneumonia Detection
# C:\Users\shameen.shrestha\Downloads\Pneumonia Detection

# %%
path = os.getcwd()
print(path)
# Out:
# C:\Users\shameen.shrestha\Downloads\Pneumonia Detection

# %%
def process_data(img_dims, batch_size):
    
    train_datagen = image_gen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )
    
    test_val_datagen = ImageDataGenerator(rescale=1./255)
    
    train_dir = os.path.join(path, 'chest_xray', 'train')
    test_dir = os.path.join(path, 'chest_xray', 'test')
    val_dir = os.path.join(path, 'chest_xray', 'val')
    
    train_gen = train_datagen.flow_from_directory(
        directory=train_dir,
        target_size=(img_dims, img_dims),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )

    test_gen = test_val_datagen.flow_from_directory(
        directory=test_dir,
        target_size=(img_dims, img_dims),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )
    
    val_gen = test_val_datagen.flow_from_directory(
        directory=val_dir,
        target_size=(img_dims, img_dims),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )
    
    test_data = []
    test_labels = []

    for cond in ['NORMAL', 'PNEUMONIA']:
        for img in (os.listdir(os.path.join(test_dir, cond))):
            img = plt.imread(os.path.join(test_dir, cond, img))
            img = cv2.resize(img, (img_dims, img_dims))
            img = np.dstack([img, img, img])
            img = img.astype('float32') / 255
            if cond == 'NORMAL':
                label = [1, 0]  # label for NORMAL
            elif cond == 'PNEUMONIA':
                label = [0, 1]  # label for PNEUMONIA
            test_data.append(img)
            test_labels.append(label)

    test_data = np.array(test_data)
    test_labels = np.array(test_labels)
    
    return train_gen, test_gen, test_data, test_labels

# %%
img_dims = 150
epochs = 10
batch_size = 20

train_gen, test_gen, test_data, test_labels = process_data(img_dims, batch_size)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %% [markdown]
# ## ResNet

# %%
base_model = ResNet50(weights='imagenet', include_top=False)

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(units=2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])


checkpoint = ModelCheckpoint('model_weights.h5', save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs', histogram_freq=0, write_graph=True, write_images=False)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1_pad (ZeroPadding2D)      (None, None, None,   0           ['input_4[0][0]']
#                                 3)
#
#  conv1_conv (Conv2D)            (None, None, None,   9472        ['conv1_pad[0][0]']
#                                 64)
#
#  conv1_bn (BatchNormalization)  (None, None, None,   256         ['conv1_conv[0][0]']
#                                 64)
#
#  conv1_relu (Activation)        (None, None, None,   0           ['conv1_bn[0][0]']
#                                 64)
#
#  pool1_pad (ZeroPadding2D)      (None, None, None,   0           ['conv1_relu[0][0]']
#                                 64)
#
# ...

# %%
# Fit the model
#ResNet = model.fit_generator(train_gen,  epochs=10, validation_data=test_gen, validation_steps=20,  callbacks=[checkpoint, tensorboard], verbose=2)
# Out:
# C:\Users\shameen.shrestha\AppData\Local\Temp\ipykernel_11620\1574454630.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   ResNet = model.fit_generator(train_gen,  epochs=10,
# Epoch 1/10
# 261/261 - 1143s - loss: 0.1440 - accuracy: 0.9427 - val_loss: 3.6829 - val_accuracy: 0.6375 - 1143s/epoch - 4s/step
# Epoch 2/10
# 261/261 - 1206s - loss: 0.0797 - accuracy: 0.9697 - val_loss: 0.7961 - val_accuracy: 0.6125 - 1206s/epoch - 5s/step
# Epoch 3/10
# 261/261 - 1175s - loss: 0.0729 - accuracy: 0.9730 - val_loss: 7.2077 - val_accuracy: 0.6375 - 1175s/epoch - 5s/step
# Epoch 4/10
# 261/261 - 1143s - loss: 0.0517 - accuracy: 0.9808 - val_loss: 2.4360 - val_accuracy: 0.6200 - 1143s/epoch - 4s/step
# Epoch 5/10
# 261/261 - 1190s - loss: 0.0484 - accuracy: 0.9826 - val_loss: 0.4063 - val_accuracy: 0.8775 - 1190s/epoch - 5s/step
# Epoch 6/10
# ...

# %%
model.save('ResNet.h5')
loaded_model_ResNet = load_model('ResNet.h5')

# %%
acc = ResNet.history['accuracy']
val_acc = ResNet.history['val_accuracy']
loss = ResNet.history['loss']
val_loss = ResNet.history['val_loss']

epochs= range(10)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs, acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Testing Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Testing Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Testing Accuracy')

# %%
plt.subplot(2, 2, 2)
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Testing Loss')
plt.legend(loc='upper right')
plt.title('Training and Testing Loss')
plt.ylim([0, 4])
plt.show()

# %%
labels = ['NORMAL', 'PNEUMONIA']

preds = loaded_model_ResNet.predict(test_data)
preds = np.argmax(preds, axis=1)
true_labels = np.argmax(test_labels, axis=1)
print("Evaluation of ResNet50")
print("\nConfusion Matrix:")
print(confusion_matrix(true_labels, preds))
print("\nClassification Report:")
print(classification_report(true_labels, preds,target_names=labels))
# Out:
# 20/20 [==============================] - 24s 1s/step
# Evaluation of ResNet50
#
# Confusion Matrix:
# [[220  14]
#  [ 42 348]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.84      0.94      0.89       234
#    PNEUMONIA       0.96      0.89      0.93       390
#
#     accuracy                           0.91       624
#    macro avg       0.90      0.92      0.91       624
# weighted avg       0.92      0.91      0.91       624

# %%
fpr, tpr, thresholds = roc_curve(true_labels, preds)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ResNet- ROC Curve')
plt.legend(loc="lower right")
plt.show()

# %%
preds = loaded_model_ResNet.predict(test_data)
pred_labels = np.argmax(preds, axis=1)
true_labels = np.argmax(test_labels, axis=1)

false_negatives = []
for i in range(len(pred_labels)):
    if pred_labels[i] == 1 and true_labels[i] == 0:
        false_negatives.append(i)
        
print("Indices of False Negatives:", false_negatives)
# Out:
# 20/20 [==============================] - 22s 1s/step
# Indices of False Negatives: [16, 119, 121, 123, 126, 129, 130, 133, 134, 135, 136, 140, 143, 144]

# %%
preds = loaded_model_VGG.predict(test_data)
pred_labels = np.argmax(preds, axis=1)
true_labels = np.argmax(test_labels, axis=1)

false_negatives = []
for i in range(len(pred_labels)):
    if pred_labels[i] == 1 and true_labels[i] == 0:
        false_negatives.append(i)
        
print("Indices of False Negatives:", false_negatives)
# Out:
# 20/20 [==============================] - 46s 2s/step
# Indices of False Negatives: [7, 16, 45, 52, 72, 87, 88, 91, 98, 103, 113, 115, 117, 118, 119, 120, 121, 122, 123, 124, 126, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 148, 174, 181, 182, 193, 197, 200, 209, 217, 220, 226, 228, 230, 231]

# %%
#Using Test Data
samples = 4
test_images = [5,135,230,620]
images = test_data[test_images]
true_labels = np.argmax(test_labels[test_images], axis=1)


preds = loaded_model_ResNet.predict(images)
pred_labels = np.argmax(preds, axis=1)
print("ResNet50: ")
plt.figure(figsize=(15, 7))
for i in range(samples):
    plt.subplot(1, samples, i+1)
    plt.imshow(images[i])
    plt.title(f'Index: {test_images[i]}: Predicted: {pred_labels[i]}, Actual: {true_labels[i]},')
    plt.axis('off')
plt.show()
plt.savefig('ResNet_example.jpeg')
# Out:
# 1/1 [==============================] - 0s 246ms/step
# ResNet50:

# %% [markdown]
# ## VGG

# %%
base_model2 = VGG16(weights='imagenet', include_top=False)
x = base_model2.output

x = Dense(256, activation='relu')(x)
output = Dense(2, activation='softmax')(x)



model2 = Model(inputs=base_model2.input, outputs=output)

model2.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])


checkpoint = ModelCheckpoint('model_weights.h5', save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs', histogram_freq=0, write_graph=True, write_images=False)
model2.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
# ...

# %%
#VGG = model2.fit_generator(train_gen,  epochs=10, validation_data=test_gen, validation_steps=20, callbacks=[checkpoint, tensorboard], verbose=2)
# Out:
# C:\Users\shameen.shrestha\AppData\Local\Temp\ipykernel_11620\2542849540.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   VGG = model2.fit_generator(train_gen,  epochs=10,
# Epoch 1/10
# 261/261 - 2518s - loss: 0.2870 - accuracy: 0.8702 - val_loss: 0.3675 - val_accuracy: 0.8625 - 2518s/epoch - 10s/step
# Epoch 2/10
# 261/261 - 2218s - loss: 0.1638 - accuracy: 0.9356 - val_loss: 0.2607 - val_accuracy: 0.9125 - 2218s/epoch - 8s/step
# Epoch 3/10
# 261/261 - 2053s - loss: 0.1316 - accuracy: 0.9479 - val_loss: 0.2303 - val_accuracy: 0.9275 - 2053s/epoch - 8s/step
# Epoch 4/10
# 261/261 - 2207s - loss: 0.1061 - accuracy: 0.9592 - val_loss: 0.1579 - val_accuracy: 0.9425 - 2207s/epoch - 8s/step
# Epoch 5/10
# 261/261 - 2219s - loss: 0.1007 - accuracy: 0.9599 - val_loss: 0.3237 - val_accuracy: 0.9075 - 2219s/epoch - 9s/step
# Epoch 6/10
# ...

# %%
model2.save('VGG.h5')
loaded_model_VGG = load_model('VGG.h5')

# %%
acc = VGG.history['accuracy']
val_acc = VGG.history['val_accuracy']
loss = VGG.history['loss']
val_loss = VGG.history['val_loss']

epochs_range = range(10)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot( acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Testing Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Testing Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Testing Accuracy')

# %%
plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Testing Loss')
plt.legend(loc='upper right')
plt.title('Training and Testing Loss')
plt.ylim([0, 4])
plt.show()

# %%
labels = ['NORMAL', 'PNEUMONIA']
preds_vgg = loaded_model_VGG.predict(test_data)

preds_vgg = np.argmax(preds_vgg, axis=1)
true_labels = np.argmax(test_labels, axis=1)

print("Evaluation of VGG16:")
print("\nConfusion Matrix:")
print(confusion_matrix(true_labels, preds_vgg))
print("\nClassification Report:")
print(classification_report(true_labels, preds_vgg,target_names=labels))
# Out:
# 20/20 [==============================] - 50s 3s/step
# Evaluation of VGG16:
#
# Confusion Matrix:
# [[181  53]
#  [  1 389]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.99      0.77      0.87       234
#    PNEUMONIA       0.88      1.00      0.94       390
#
#     accuracy                           0.91       624
#    macro avg       0.94      0.89      0.90       624
# weighted avg       0.92      0.91      0.91       624

# %%
fpr, tpr, thresholds = roc_curve(true_labels, preds_vgg)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('VGG- ROC Curve')
plt.legend(loc="lower right")
plt.show()

# %%
#Using Test Data
samples = 4
test_images = [5,135,230,620]
images = test_data[test_images]
true_labels = np.argmax(test_labels[test_images], axis=1)


preds = loaded_model_VGG.predict(images)
pred_labels = np.argmax(preds, axis=1)
print("VGG16")
plt.figure(figsize=(15, 7))
for i in range(samples):
    plt.subplot(1, samples, i+1)
    plt.imshow(images[i])

    plt.title(f'Index: {test_images[i]}: Predicted: {pred_labels[i]}, Actual: {true_labels[i]},')
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 321ms/step
# VGG16

# %% [markdown]
# ## Class Activation Map

# %%
img_paths = ['chest_xray/train/PNEUMONIA/person3_bacteria_10.jpeg', 'chest_xray/train/NORMAL/IM-0119-0001.jpeg']

# %%
output_dir = os.path.join(path, 'output', 'ResNet')
model_path = 'ResNet50.h5'


def get_output_layer(model, layer_name):
    layer_dict = dict([(layer.name, layer) for layer in model.layers])
    layer = layer_dict[layer_name]
    return layer

def visualize_class_activation_map(model_path, img_paths, output_dir):
    model = load_model(model_path)

    for img_path in img_paths:
        original_img = cv2.imread(img_path, 1)
        width, height, _ = original_img.shape

        
        class_weights = model.layers[-1].get_weights()[0]

      
        final_conv_layer = get_output_layer(model, "conv5_block3_out")
        get_output = K.function([model.layers[0].input], [final_conv_layer.output, model.layers[-1].output])
        [conv_outputs, predictions] = get_output([np.expand_dims(original_img, axis=0)])
        conv_outputs = conv_outputs[0, :, :, :]

        
        cam = np.zeros(dtype=np.float32, shape=conv_outputs.shape[0:2])
        for i, w in enumerate(class_weights[:, 1]):
            cam += w * conv_outputs[:, :, i]
        print("predictions", predictions)
        cam /= np.max(cam)
        cam = cv2.resize(cam, (height, width))
        heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
        heatmap[np.where(cam < 0.2)] = 0
        img = heatmap * 0.5 + original_img
        output_path = os.path.join(output_dir, os.path.basename(img_path))
        cv2.imwrite(output_path, img)
        



visualize_class_activation_map(model_path, img_paths, output_dir)
# Out:
# predictions [[0. 1.]]
# predictions [[0. 1.]]

# %%
output_dir = os.path.join(path, 'output', 'VGG')
model_path = 'VGG.h5'

def get_output_layer(model, layer_name):
    layer_dict = dict([(layer.name, layer) for layer in model.layers])
    layer = layer_dict[layer_name]
    return layer

def visualize_class_activation_map(model_path, img_paths, output_dir):
    model = load_model(model_path)

    for img_path in img_paths:
        original_img = cv2.imread(img_path, 1)
        width, height, _ = original_img.shape

        
        class_weights = model.layers[-1].get_weights()[0]

      
        final_conv_layer = get_output_layer(model, "block5_conv3")
        get_output = K.function([model.layers[0].input], [final_conv_layer.output, model.layers[-1].output])
        [conv_outputs, predictions] = get_output([np.expand_dims(original_img, axis=0)])
        conv_outputs = conv_outputs[0, :, :, :]

        
        cam = np.zeros(dtype=np.float32, shape=conv_outputs.shape[0:2])
        for i, w in enumerate(class_weights[:, 1]):
            cam += w * conv_outputs[:, :, i]
        print("predictions", predictions)
        cam /= np.max(cam)
        cam = cv2.resize(cam, (height, width))
        heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
        heatmap[np.where(cam < 0.2)] = 0
        img = heatmap * 0.5 + original_img
        output_path = os.path.join(output_dir, os.path.basename(img_path))
        cv2.imwrite(output_path, img)
        



visualize_class_activation_map(model_path, img_paths, output_dir)
# Out:
# predictions [[5.1530305e-06 9.9999487e-01]]
# predictions [[5.5952543e-05 9.9994409e-01]]
